# %%
from utils_ur5 import *

# %%
robot = UR5Robot()
plans = robot.move_to_pose(robot.ROBOT_WS_INIT)

# %%
# %matplotlib notebook
color, depth = robot.get_view(robot.ROBOT_WS_INIT, show_img=True)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
robot.pixel2pos(depth, np.array([588, 216]))
# Out:
# array([-0.13902508, -0.61418561, -0.02527793])

# %%
#plans = robot.move_to_pose([0.07946, -0.4731, 0.19], grasp=1.0)

# %%
#color, depth = robot.push_from_pixel(depth, 593, 335, np.pi/2)

# %%
color, depth = robot.push_from_pixel(depth, 677, 252, 5*np.pi/4)
